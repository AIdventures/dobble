# %% [markdown]
# ## Import libraries

# %%
import os
from tqdm.notebook import tqdm
import face_recognition
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Load the dataframe and images

# %% [markdown]
# ## Get system paths

# %%
PRADO_PATH = os.getenv("PRADO_PATH")
assert PRADO_PATH is not None, f"Please set the env variable PRADO_PATH"
assert os.path.isdir(PRADO_PATH), "PRADO_PATH must be a dir"

# %% [markdown]
# ## Read Prado museum dataframe

# %%
df = pd.read_csv(os.path.join(PRADO_PATH, "prado.csv"))
df["work_id"] = df['work_image_url'].apply(lambda x: x.split('/')[-1])
print(f"The dataframe has {len(df)} rows")
df.tail()
# Out:
# The dataframe has 13487 rows
#                                                 work_url  \
# 13482  https://www.museodelprado.es/coleccion/obra-de...
# 13483  https://www.museodelprado.es/coleccion/obra-de...
# 13484  https://www.museodelprado.es/coleccion/obra-de...
# 13485  https://www.museodelprado.es/coleccion/obra-de...
# 13486  https://www.museodelprado.es/coleccion/obra-de...
#
#                                           work_image_url  \
# 13482  https://content3.cdnprado.net/imagenes/Documen...
# 13483  https://content3.cdnprado.net/imagenes/Documen...
# 13484  https://content3.cdnprado.net/imagenes/Documen...
# 13485  https://content3.cdnprado.net/imagenes/Documen...
# 13486  https://content3.cdnprado.net/imagenes/Documen...
#
#                                author  \
# 13482       Atribuido Falck, Jeremías
# 13483        Atribuido Kiyonobu, Tori
# 13484                  García, Sergio
# 13485                         Anónimo
# 13486  Goya y Lucientes, Francisco de
#
#                                               author_bio  \
# 13482  Gdansk/Danzig (Polonia), 1609 - Gdansk/Danzig ...
# 13483                                         1664, 1729
# 13484  Madrid, 1813 - Madrid, 1855\n\nHijo de Nicolás...
# 13485                                                NaN
# 13486  Fuendetodos, Zaragoza, 1746 - Burdeos (Francia...
#
#                                               author_url  \
# 13482  https://www.museodelprado.es/coleccion/artista...
# 13483  https://www.museodelprado.es/coleccion/artista...
# 13484  https://www.museodelprado.es/coleccion/artista...
# 13485  https://www.museodelprado.es/coleccion/artista...
# 13486  https://www.museodelprado.es/coleccion/artista...
#
#                                   author_id  \
# 13482  d351c3c1-e89b-49cf-900d-24085ed1908f
# 13483  9e420297-9fb9-4ef3-b128-96596d5dc191
# 13484  d984cdeb-020c-41f9-ae68-3285aebfa25a
# 13485  99d7590d-7ec8-4da4-bc2f-92064214c76c
# 13486  39568a17-81b5-4d6f-84fa-12db60780812
#
#                                               work_title  \
# 13482                Vista del monasterio de El Escorial
# 13483                         Daifukucho [Sankai Nagoya]
# 13484                                    Retrato de dama
# 13485  Vista del río Buñol con algunas construcciones...
# 13486  Letras I B B, o IB unidas como un monograma en...
#
#                                            work_subtitle work_exposed  \
# 13482  1662 - 1672. Aguafuerte, Buril, Estampa ilumin...  No expuesto
# 13483  1697. Entalladura [madera a la fibra] sobre pa...  No expuesto
# 13484               Mediados del siglo XIX. , 5,8 x 5 cm  No expuesto
# 13485  Antes de  1918. Gelatina / Colodión sobre plac...  No expuesto
# 13486  1771 - 1774. Lápiz negro sobre papel verjurado...  No expuesto
#
#                                         work_description  \
# 13482  Cervera Vera (Escorial en BN no C20-a, Real Bi...
# 13483  Antigua atribución a Hishikawa Moronobu. En es...
# 13484  Este retrato femenino es una obra de calidad e...
# 13485  Vista del río Buñol a su paso por la zona del ...
# 13486  En la página 91 del Cuaderno (D06068/091) apar...
#
#                                                work_tags  \
# 13482  Aguafuerte;Buril;Estampa iluminada;Papel verju...
# 13483  Entalladura [madera a la fibra];Papel japonés;...
# 13484  Aguada de pigmentos opacos [gouache, témpera];...
# 13485  Buñol y alrededores;Gelatina / Colodión;Placa ...
# 13486  Cuaderno italiano de Goya;Lápiz negro;Papel ve...
#
#       technical_sheet_numero_de_catalogo           technical_sheet_autor  \
# 13482                            G002860       Atribuido Falck, Jeremías
# 13483                            G005639        Atribuido Kiyonobu, Tori
# 13484                            O003393                  García, Sergio
# 13485                            HF05937             Anónimo -Fotógrafo-
# 13486                        D006068/156  Goya y Lucientes, Francisco de
#
#                                   technical_sheet_titulo  \
# 13482                Vista del monasterio de El Escorial
# 13483                         Daifukucho [Sankai Nagoya]
# 13484                                    Retrato de dama
# 13485  Vista del río Buñol con algunas construcciones...
# 13486  Letras I B B, o IB unidas como un monograma en...
#
#         technical_sheet_fecha  \
# 13482             1662 - 1672
# 13483       1697 (Genroku 10)
# 13484  Mediados del siglo XIX
# 13485          Antes de  1918
# 13486             1771 - 1774
#
#                                  technical_sheet_tecnica  \
# 13482               Aguafuerte; Buril; Estampa iluminada
# 13483                    Entalladura [madera a la fibra]
# 13484  Aguada de pigmentos opacos [gouache, témpera];...
# 13485                                Gelatina / Colodión
# 13486                                        Lápiz negro
#
#          technical_sheet_soporte             technical_sheet_dimension  \
# 13482  Papel verjurado, ahuesado  Alto: 474 mm;\n\n\n\n\nAncho: 756 mm
# 13483              Papel japonés  Alto: 172 mm;\n\n\n\n\nAncho: 240 mm
# 13484                     Marfil    Alto: 5,8 cm;\n\n\n\n\nAncho: 5 cm
# 13485            Placa de vidrio   Alto: 44 mm;\n\n\n\n\nAncho: 106 mm
# 13486            Papel verjurado  Alto: 186 mm;\n\n\n\n\nAncho: 130 mm
#
#            technical_sheet_serie  \
# 13482                        NaN
# 13483                        NaN
# 13484                        NaN
# 13485        Buñol y alrededores
# 13486  Cuaderno italiano de Goya
#
#                              technical_sheet_procedencia  \
# 13482                Colección José María Cervelló, 2003
# 13483  Nippon Hanga Kyokai [Socidad de Pintores y Gra...
# 13484  Alcalá Subastas, Madrid 28 de mayo 2015; Donac...
# 13485  Donación Ana y Cecilio Ellacuria Delgado, here...
# 13486  Colección particular, Palma de Mallorca; Edmun...
#
#                                             bibliography  \
# 13482  Cervera Vera, Luis,  Las Estampas y el Sumario...
# 13483  Bru, R.,  Ukiyo-e en Madrid: las estampas del ...
# 13484  Espinosa Martín, Mari Carmen.,  Iluminaciones,...
# 13485  Sánchez Torija, Beatriz,  Cecilio Pla y su rel...
# 13486  Wilson- Bareau, Juliet; Mena Marqués, Manuela,...
#
#                                                inventory  \
# 13482  Inv. Colección Cervelló.\nNúm. 166201.\n@@@\nI...
# 13483  Inv. Dibujos siglo XIX, Casón del Buen Retiro....
# 13484  Inv. Nuevas Adquisiciones (iniciado en 1856).\...
# 13485  Inv. Nuevas Adquisiciones (iniciado en 1856).\...
# 13486  Inv. Dibujos, Fondo Antiguo.\nNúm. 1732.\n@@@\...
#
#                                              expositions  \
# 13482                                                NaN
# 13483    DOUANES / VI-G y Cruz de Suiza\nSello.\nAnverso
# 13484  S.García\nManuscrito a pincel.\nAnverso, marge...
# 13485  Elemento de arquitectura:\n\n\n\n\n Chimenea d...
# 13486  I B B // [...] o y [?]\nManuscrito con lápiz n...
#
#                                                ubication  \
# 13482                                                NaN
# 13483  Estampas japonesas en el Museo del Prado\n    ...
# 13484                                                NaN
# 13485                                                NaN
# 13486  Roma en el bolsillo. Cuadernos de dibujo y apr...
#
#        technical_sheet_autores technical_sheet_edicion_/_estado  \
# 13482                      NaN                              NaN
# 13483                      NaN                              NaN
# 13484                      NaN                              NaN
# 13485                      NaN                              NaN
# 13486                      NaN                              NaN
#
#       technical_sheet_materia technical_sheet_ceca technical_sheet_autora  \
# 13482                     NaN                  NaN                    NaN
# 13483                     NaN                  NaN                    NaN
# 13484                     NaN                  NaN                    NaN
# 13485                     NaN                  NaN                    NaN
# 13486                     NaN                  NaN                    NaN
#
#       technical_sheet_lugar_de_produccion  \
# 13482                                 NaN
# 13483                                 NaN
# 13484                                 NaN
# 13485                              España
# 13486                                 NaN
#
#                                         work_id
# 13482  c62f7f3e-3ad3-4d9e-9586-b0b389b2d032.jpg
# 13483  6c28accf-e0c0-4bc0-b4c6-3fbb282bcbd8.jpg
# 13484  b4126fb6-c5ac-40e3-89a1-d1578914c09b.jpg
# 13485  e7bf2481-522c-4071-9d97-7908aca45831.jpg
# 13486  e8d785a8-1407-4203-b837-2d01e82a36cb.jpg

# %% [markdown]
# # Faces to embedding database

# %%
DETECTION_MODEL = "hog"  # hog - cnn
COLLECTION_NAME = f"{DETECTION_MODEL}_faces"

# %% [markdown]
# ## Create ChromaDB collection

# %%
import uuid
import chromadb

# %%
from chromadb.config import Settings
client = chromadb.Client(Settings(
    chroma_db_impl="duckdb+parquet",
    persist_directory="chromadb" # Optional, defaults to .chromadb/ in the current directory
))
client.persist()
# Out:
# True

# %%
# Delete a collection and all associated embeddings, documents, and metadata.
# ⚠️ This is destructive and not reversible
#client.delete_collection(name=COLLECTION_NAME)

# %%
collection = client.get_or_create_collection(name=COLLECTION_NAME)
print(f"Items in collection: {collection.count()}")
# Out:
# Items in collection: 0

# %% [markdown]
# ## Iterate over the dataframe/faces

# %%
errors = {"not_found": [], "location_embeddings_mismatch": []}
for _, row in tqdm(df.iterrows(), total=len(df)):
    
    image_id = row["work_id"]

    image_path = os.path.join(PRADO_PATH, "images", image_id)
    if not os.path.exists(image_path):
        # f"Image path not found: '{image_path}'"
        errors["not_found"].append(image_path)
        continue
    
    image = face_recognition.load_image_file(image_path)
    
    # https://face-recognition.readthedocs.io/en/latest/face_recognition.html#face_recognition.api.face_locations
    faces_locations = face_recognition.face_locations(
        image,
        model=DETECTION_MODEL,
        number_of_times_to_upsample=1
    )

    faces_embeddings = face_recognition.face_encodings(
        image,
        known_face_locations=faces_locations,
        num_jitters=1,
        model="large"
    )

    if not len(faces_locations) == len(faces_embeddings):
        # f"{len(faces_locations)} faces founds but {len(faces_embeddings)} embeddings generated"    
        errors["location_embeddings_mismatch"].append(image_path)
        continue
    
    for indx, (face_location, face_embedding) in enumerate(zip(faces_locations, faces_embeddings)):
    
        # Get the location of each face in this image
        top, right, bottom, left = face_location
        width = abs(right - left)
        height = abs(bottom - top)

        collection.add(
            embeddings=face_embedding.tolist(),
            metadatas={
                "image_id": image_id,
                "fl_top": top,
                "fl_right": right,
                "fl_bottom": bottom,
                "fl_left": left,
                "width": width,
                "height": height
            },
            ids=[uuid.uuid4().hex]
        )
# Out:
#   0%|          | 0/13487 [00:00<?, ?it/s]

# %%
collection.count()

# %%
collection.peek(limit=3)
# Out:
# {'ids': ['2301110bf2a4438a95311e31735520e7',
#   '9fe8edec6ae54d4980be6a093fa536d9',
#   'eee879fb47894414b3bf17f29569b390'],
#  'embeddings': [[-0.11147989332675934,
#    0.027456363663077354,
#    0.09670601785182953,
#    -0.08006956428289413,
#    -0.18422652781009674,
#    -0.05528806895017624,
#    0.010502303950488567,
#    -0.11511560529470444,
#    0.057787615805864334,
#    -0.18120616674423218,
#    0.1493380218744278,
#    -0.07502460479736328,
#    -0.20317897200584412,
#    0.12211953848600388,
#    -0.02773684449493885,
#    0.11262436956167221,
#    -0.07674969732761383,
#    -0.07970723509788513,
#    -0.09246359020471573,
#    -0.13784505426883698,
#    0.017547380179166794,
#    0.14324739575386047,
#    -0.07297954708337784,
#    0.05694309622049332,
#    -0.06750456243753433,
#    -0.21837878227233887,
#    -0.04442638158798218,
#    -0.01011237408965826,
#    0.09819069504737854,
#    -0.011019645258784294,
#    -0.041496772319078445,
#    0.026156168431043625,
#    -0.15635812282562256,
#    0.027410579845309258,
#    0.035372231155633926,
#    0.03920159488916397,
#    -0.10885372012853622,
#    -0.10667689144611359,
#    0.18619926273822784,
#    0.0069396342150866985,
#    -0.2265041470527649,
#    -0.05250876769423485,
#    0.09208923578262329,
#    0.24887995421886444,
#    0.20469295978546143,
#    -0.013159261085093021,
#    -0.005894606001675129,
#    -0.019610712304711342,
#    0.15561003983020782,
#    -0.24699102342128754,
#    0.014283437281847,
#    0.07448942214250565,
#    0.1432291865348816,
#    0.05298702046275139,
#    0.07123272120952606,
#    -0.18909353017807007,
#    0.007447521667927504,
#    0.10827002674341202,
#    -0.10878146439790726,
#    0.039140842854976654,
#    0.08359720557928085,
#    -0.12393017113208771,
#    0.022845149040222168,
#    -0.06918831914663315,
#    0.2189905345439911,
#    0.06844832003116608,
#    -0.09468675404787064,
#    -0.12633946537971497,
#    0.17919759452342987,
#    -0.2600904107093811,
#    -0.09869913011789322,
#    0.04878677427768707,
#    -0.08563373982906342,
#    -0.0718032643198967,
#    -0.287797212600708,
#    -0.018804803490638733,
#    0.33206456899642944,
#    0.15306921303272247,
#    -0.12195166945457458,
#    0.16801580786705017,
#    -0.18912866711616516,
#    -0.08282212913036346,
#    0.07145748287439346,
#    -0.09817389398813248,
#    -0.14321155846118927,
#    -0.23187561333179474,
#    -0.019118821248412132,
#    0.36670589447021484,
#    0.22359219193458557,
#    -0.14526821672916412,
#    -0.02286321111023426,
#    -0.02076144516468048,
#    0.041138265281915665,
#    0.07913421839475632,
#    0.002110073110088706,
#    -0.1233566552400589,
#    -0.07075168937444687,
#    -0.13541482388973236,
#    -0.0015918652061372995,
#    0.22527258098125458,
#    -0.017568085342645645,
#    -0.005114847328513861,
#    0.1952582597732544,
#    0.03605049476027489,
#    -0.02310667559504509,
#    -0.023023696616292,
#    0.027009034529328346,
#    -0.03630179166793823,
#    -0.0676586776971817,
#    -0.039622269570827484,
#    0.01042898092418909,
#    -0.05320221930742264,
#    -0.11804895102977753,
#    0.012665675021708012,
#    0.14559851586818695,
#    -0.17274434864521027,
#    0.1666199266910553,
#    -0.020352071151137352,
#    0.014380966313183308,
#    -0.09569967538118362,
#    0.07014085352420807,
#    -0.016794433817267418,
#    0.007467629853636026,
#    0.1604466587305069,
#    -0.16639026999473572,
#    0.17541219294071198,
#    0.22592809796333313,
#    -0.004316228441894054,
#    0.07844320684671402,
#    0.042141132056713104,
#    0.01647217944264412,
#    -0.06167605519294739,
#    -0.08204773813486099,
#    -0.10892139375209808,
#    -0.14493422210216522,
#    0.0026800474151968956,
#    -0.08423429727554321,
#    0.02022998407483101,
#    0.039783503860235214]],
#  'documents': [None, None, None],
#  'metadatas': [{'image_id': 'ad760d28-efc9-44ad-816c-98c197994faf.jpg',
#    'fl_top': 282,
#    'fl_right': 683,
#    'fl_bottom': 411,
#    'fl_left': 554,
#    'width': 129,
#    'height': 129},
#   {'image_id': '89d84fcb-a7f4-43c0-a6f6-51ea131ef7b8.jpg',
#    'fl_top': 655,
#    'fl_right': 1315,
#    'fl_bottom': 841,
#    'fl_left': 1129,
#    'width': 186,
#    'height': 186},
#   {'image_id': '55bd8127-2be9-4e69-bd74-cb138735bd10.jpg',
#    'fl_top': 826,
#    'fl_right': 527,
#    'fl_bottom': 901,
#    'fl_left': 453,
#    'width': 74,
#    'height': 75}]}

# %% [markdown]
# ### Query

# %%
collection.query(
    query_embeddings=face_embedding.tolist(),
    n_results=2,
    #where={"metadata_field": "is_equal_to_this"},
    #where_document={"$contains":"search_string"}
)
# Out:
# {'ids': [['240cd90bd086477f82c897d94f9c0524',
#    '4b76e5bc992b47b8b08428331e15656e']],
#  'embeddings': None,
#  'documents': [[None, None]],
#  'metadatas': [[{'image_id': '02e90b75-fce3-4cef-8d7e-36c716507a1d.jpg',
#     'fl_top': 547,
#     'fl_right': 561,
#     'fl_bottom': 615,
#     'fl_left': 493,
#     'width': 68,
#     'height': 68},
#    {'image_id': '02e90b75-fce3-4cef-8d7e-36c716507a1d.jpg',
#     'fl_top': 430,
#     'fl_right': 264,
#     'fl_bottom': 498,
#     'fl_left': 196,
#     'width': 68,
#     'height': 68}]],
#  'distances': [[0.0, 0.2524358332157135]]}
